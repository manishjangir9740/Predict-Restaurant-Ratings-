# %%
import pandas as pd
import numpy as np

# %%
# Load the dataset
data = pd.read_csv('Dataset .csv')

# %%
data
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
# Drop multiple columns
columns_to_drop = ['Restaurant ID', 'Restaurant Name', 'Country Code', 'City',
                   'Address', 'Locality', 'Locality Verbose', 'Longitude',
                   'Latitude', 'Cuisines', 'Currency']

data.drop(columns_to_drop, axis=1, inplace=True)

# %%
data
# Out:
#       Average Cost for two Has Table booking Has Online delivery  \
# 0                     1100               Yes                  No
# 1                     1200               Yes                  No
# 2                     4000               Yes                  No
# 3                     1500                No                  No
# 4                     1500               Yes                  No
# ...                    ...               ...                 ...
# 9546                    80                No                  No
# 9547                   105                No                  No
# 9548                   170                No                  No
# 9549                   120                No                  No
# 9550                    55                No                  No
#
#      Is delivering now Switch to order menu  Price range  Aggregate rating  \
# 0                   No                   No            3               4.8
# ...

# %%
# Display cleaned dataset
print("Cleaned Dataset:")
print(data.head())
# Out:
# Cleaned Dataset:
#    Average Cost for two Has Table booking Has Online delivery  \
# 0                  1100               Yes                  No
# 1                  1200               Yes                  No
# 2                  4000               Yes                  No
# 3                  1500                No                  No
# 4                  1500               Yes                  No
#
#   Is delivering now Switch to order menu  Price range  Aggregate rating  \
# 0                No                   No            3               4.8
# 1                No                   No            3               4.5
# 2                No                   No            4               4.4
# 3                No                   No            4               4.9
# 4                No                   No            4               4.8
#
#   Rating color Rating text  Votes
# 0   Dark Green   Excellent    314
# 1   Dark Green   Excellent    591
# ...

# %%
# Check dataset shape
print("\nDataset Shape:", data.shape)
# Out:
# Dataset Shape: (9551, 10)

# %%
# Display dataset information
print("\nDataset Information:")
print(data.info())
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Average Cost for two  9551 non-null   int64
#  1   Has Table booking     9551 non-null   object
#  2   Has Online delivery   9551 non-null   object
#  3   Is delivering now     9551 non-null   object
#  4   Switch to order menu  9551 non-null   object
#  5   Price range           9551 non-null   int64
#  6   Aggregate rating      9551 non-null   float64
#  7   Rating color          9551 non-null   object
#  8   Rating text           9551 non-null   object
#  9   Votes                 9551 non-null   int64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 746.3+ KB
# None

# %%
# Display descriptive statistics
print("\nDescriptive Statistics:")
print(data.describe())
# Out:
# Descriptive Statistics:
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# 25%              250.000000     1.000000          2.500000      5.000000
# 50%              400.000000     2.000000          3.200000     31.000000
# 75%              700.000000     2.000000          3.700000    131.000000
# max           800000.000000     4.000000          4.900000  10934.000000

# %%
# Check for missing values
print("\nMissing Values:")
print(data.isnull().sum())
# Out:
# Missing Values:
# Average Cost for two    0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
# Check for duplicated rows
print("\nDuplicated Rows:", data.duplicated().sum())
# Out:
# Duplicated Rows: 2871

# %%
# Remove rows with missing values
data.dropna(inplace=True)

# %%
# Visualize price range distribution
import matplotlib.pyplot as plt
import seaborn as sb

# %%
data['Price range'].value_counts().plot(kind='pie', autopct='%1.2f%%',
                                      colors=['darkred', 'darkgreen', 'darkblue', 'darkorange'])
# Out:
# <Axes: ylabel='count'>

# %%
import matplotlib.pyplot as plt

# Get value counts of 'Aggregate rating'
rating_counts = data['Aggregate rating'].value_counts()

# Plot pie chart
plt.pie(rating_counts, labels=rating_counts.index, autopct='%.2f')
plt.title('Aggregate Rating Distribution (Dark Rainbow Colors)')
plt.show()

# %%
import seaborn as sb
import matplotlib.pyplot as plt

# Create the distribution plot using displot
sb.displot(data['Aggregate rating'], color='darkblue', kde=True, line_kws={'color': 'darkred'})

# Set the title
plt.title('Distribution of Aggregate Rating')

# Show the plot
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Get value counts of 'Price range'
price_range_counts = data['Price range'].value_counts()

# Plot pie chart
plt.pie(price_range_counts, labels=price_range_counts.index, autopct='%1.2f%%')
plt.title('Price Range Distribution')
plt.show()

# %%
import seaborn as sb
import matplotlib.pyplot as plt

# Create the distribution plot using histplot
sb.histplot(data['Price range'], color='darkgreen', kde=True, line_kws={'color': 'darkblue'})

# Set the title
plt.title('Distribution of Price Ranges')

# Show the plot
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Create the distribution plots using histplot
plt.figure(figsize=(10, 5))
sb.histplot(data['Aggregate rating'], color='darkblue', kde=True, line_kws={'color': 'darkred'})
sb.histplot(data['Price range'], color='darkgreen', kde=True, line_kws={'color': 'darkblue'})
plt.title('Distribution of Aggregate Rating and Price Ranges')

# Show the plot
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Bar plot of votes by rating text and color
sb.barplot(x=data['Rating text'], y=data['Votes'], hue=data['Rating color'])
plt.title('Votes by Rating Text and Color')
plt.xlabel('Rating Text')
plt.ylabel('Votes')
# Out:
# Text(0, 0.5, 'Votes')

# %%
ax = sb.scatterplot(x=data["Aggregate rating"], y=data["Votes"], hue=data["Price range"])

# Set the title
ax.set_title('Scatter Plot of Aggregate Rating vs. Votes')

# Show the plot
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Regression analysis

# Linear Regression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score# Encode categorical variables
from sklearn.preprocessing import LabelEncoder
     

label_encoder = LabelEncoder()
data['Has Table booking'] = label_encoder.fit_transform(data['Has Table booking'])
data['Has Online delivery'] = label_encoder.fit_transform(data['Has Online delivery'])
data['Is delivering now'] = label_encoder.fit_transform(data['Is delivering now'])
data['Switch to order menu'] = label_encoder.fit_transform(data['Switch to order menu'])
data['Rating color'] = label_encoder.fit_transform(data['Rating color'])
data['Rating text'] = label_encoder.fit_transform(data['Rating text'])

# %%
# Display encoded dataset
print("\nEncoded Dataset:")
print(data.head())
# Out:
# Encoded Dataset:
#    Average Cost for two  Has Table booking  Has Online delivery  \
# 0                  1100                  1                    0
# 1                  1200                  1                    0
# 2                  4000                  1                    0
# 3                  1500                  0                    0
# 4                  1500                  1                    0
#
#    Is delivering now  Switch to order menu  Price range  Aggregate rating  \
# 0                  0                     0            3               4.8
# 1                  0                     0            3               4.5
# 2                  0                     0            4               4.4
# 3                  0                     0            4               4.9
# 4                  0                     0            4               4.8
#
#    Rating color  Rating text  Votes
# 0             0            1    314
# 1             0            1    591
# ...

# %%
# Correlation heatmap
correlation_matrix = data.corr()
plt.figure(figsize=(10, 8))
sb.heatmap(correlation_matrix, annot=True, cmap='viridis', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %%
# Regression analysis

# Linear Regression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
     

x = data.drop('Aggregate rating', axis=1)
y = data['Aggregate rating']
     

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=353)
     

reg = LinearRegression()
reg.fit(x_train, y_train)
y_pred = reg.predict(x_test)

# %%
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error (MSE): {mse:.2f}")
# Out:
# Mean Squared Error (MSE): 1.36

# %%
r2 = r2_score(y_test, y_pred)
print(f"R-squared (R2) Error: {r2:.2f}")
# Out:
# R-squared (R2) Error: 0.45

# %%
from sklearn.tree import DecisionTreeRegressor, plot_tree
import matplotlib.pyplot as plt

def train_and_evaluate_decision_tree(x, y, test_size=0.1, random_state=105, min_samples_leaf=0.0001):
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=test_size, random_state=random_state)
    DTree = DecisionTreeRegressor(min_samples_leaf=min_samples_leaf)
    DTree.fit(x_train, y_train)
    y_predict = DTree.predict(x_test)
    r2 = r2_score(y_test, y_predict)
    print("R-squared score:", r2)
train_and_evaluate_decision_tree(x, y)
# Out:
# R-squared score: 0.9772646771353274

# %%
# Decision Tree Regressor
from sklearn.tree import DecisionTreeRegressor

# %%
DTree = DecisionTreeRegressor(min_samples_leaf=0.0001)
DTree.fit(x_train, y_train)
y_predict = DTree.predict(x_test)

# %%
mse = mean_squared_error(y_test, y_predict)
print(f"Mean Squared Error (MSE): {mse:.2f}")
# Out:
# Mean Squared Error (MSE): 0.06

# %%
r2 = r2_score(y_test, y_predict)
print(f"R-squared (R2) Error: {r2:.2f}")
# Out:
# R-squared (R2) Error: 0.98

# %%
# Conclusion
print("\nConclusion: Decision Tree Regressor model is performing exceptionally well on the test data.")
# Out:
# Conclusion: Decision Tree Regressor model is performing exceptionally well on the test data.
